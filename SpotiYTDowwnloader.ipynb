# %% [markdown]
# <a href="https://colab.research.google.com/github/HeryTroop01/Spoti_DL/blob/main/SpotiYTDowwnloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get -qq update
# !apt-get -qq install ffmpeg
# !pip -q install yt-dlp
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.8/183.8 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 65.9 MB/s eta 0:00:00

# %%
import yt_dlp
from pathlib import Path

# Ask for song name
song = input("Enter song name: ").strip()

# Output folder
output_folder = Path("downloads")
output_folder.mkdir(exist_ok=True)

ydl_opts = {
    "format": "bestaudio/best",
    "outtmpl": str(output_folder / "%(title)s.%(ext)s"),
    "default_search": "ytsearch1",   # Search YouTube and pick the first result
    "noplaylist": True,
    "quiet": False,

    "postprocessors": [{
        "key": "FFmpegExtractAudio",
        "preferredcodec": "mp3",
        "preferredquality": "320",
    }],
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([song])

print("\nDownload completed!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4968/2356317213.py in <cell line: 0>()
#       3
#       4 # Ask for song name
# ----> 5 song = input("Enter song name: ").strip()
#       6
#       7 # Output folder
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from google.colab import files
import glob

for file in glob.glob("downloads/*.mp3"):
    files.download(file)

# %%
import yt_dlp
from pathlib import Path

# Ask for song name
songs = [
    "Bombay Ponnu", "Pavizha Malligaiye", "Chinna Thamarai", "June Ponal", "Nakka Mukka",
    "Nakka Mukka", "Aval", "Kadhal Sadugudu", "Pia Pia", "Varaya Varaya", "Vaarayo Vaarayo",
    "Thozhiya", "Ey Sandakaara", "Kodana Kodi", "Kanni Theevu Ponna", "Mannarkudi Kalakalakka",
    "Ussumu Laresey", "Mascara", "Karikalan", "Makkayala Makkayala", "Kan Irandil", "Kannamma",
    "Uchimandai", "Aadungada Enna Suthi", "O Podu", "Puli Urumudhu", "Ichu Ichu", "God Mode",
    "Dialamo Dialamo", "Ennadi Maayavi Nee", "Neduvaali", "Macha Kanni", "Neruppae", "Macha Kanni",
    "Kadhalikkum Aasai", "Nenjukulle", "Dheemthanakka Thillana", "Ayyarettu", "Sathikadi", "Kangal Irandal",
    "Sonna Puriyadhu", "Kaar Kuzhal Kadavaiye", "Vaadi Vaadi", "Yaanji", "Maayam Seidhayo", "Don'u Don'u Don'u",
    "Melliname Melliname", "Thaen Thaen Thaen"]
# Output folder
output_folder = Path("downloads")
output_folder.mkdir(exist_ok=True)

ydl_opts = {
    "format": "bestaudio/best",
    "outtmpl": str(output_folder / "%(title)s.%(ext)s"),
    "default_search": "ytsearch1",   # Search YouTube and pick the first result
    "noplaylist": True,
    "quiet": False,

    "postprocessors": [{
        "key": "FFmpegExtractAudio",
        "preferredcodec": "mp3",
        "preferredquality": "320",
    }],
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    for song in songs:
        ydl.download([song])

print("\nDownload completed!")
# Out:
# [generic] Extracting URL: Bombay Ponnu
# [youtube:search] Extracting URL: ytsearch1:Bombay Ponnu
# [download] Downloading playlist: Bombay Ponnu
# [youtube:search] query "Bombay Ponnu": Downloading web client config
# [youtube:search] query "Bombay Ponnu" page 1: Downloading API JSON
# [youtube:search] Playlist Bombay Ponnu: Downloading 1 items of 1
# [download] Downloading item 1 of 1
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cAq1b7Ssssc
# [youtube] cAq1b7Ssssc: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] cAq1b7Ssssc: Downloading android vr player API JSON
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] cAq1b7Ssssc: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ---------------------------------------------------------------------------
# ExtractorError                            Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in wrapper(self, *args, **kwargs)
#    1731                 try:
# -> 1732                     return func(self, *args, **kwargs)
#    1733                 except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in __extract_info(self, url, ie, download, extra_info, process)
#    1866         try:
# -> 1867             ie_result = ie.extract(url)
#    1868         except UserNotLive as e:
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/extractor/common.py in extract(self, url)
#     764                         url if self.get_param('verbose') else truncate_string(url, 100, 20)))
# --> 765                     ie_result = self._real_extract(url)
#     766                     if ie_result is None:
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/extractor/youtube/_video.py in _real_extract(self, url)
#    4062                     )
# -> 4063                 self.raise_no_formats(reason, expected=True)
#    4064
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/extractor/common.py in raise_no_formats(self, msg, expected, video_id)
#    1271         else:
# -> 1272             raise ExtractorError(msg, expected=expected, video_id=video_id)
#    1273
#
# ExtractorError: [youtube] cAq1b7Ssssc: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
# During handling of the above exception, another exception occurred:
#
# DownloadError                             Traceback (most recent call last)
# /tmp/ipykernel_4968/3804985982.py in <cell line: 0>()
#      33 with yt_dlp.YoutubeDL(ydl_opts) as ydl:
#      34     for song in songs:
# ---> 35         ydl.download([song])
#      36
#      37 print("\nDownload completed!")
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in download(self, url_list)
#    3713
#    3714         for url in url_list:
# -> 3715             self.__download_wrapper(self.extract_info)(
#    3716                 url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3717
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in wrapper(*args, **kwargs)
#    3686         def wrapper(*args, **kwargs):
#    3687             try:
# -> 3688                 res = func(*args, **kwargs)
#    3689             except CookieLoadError:
#    3690                 raise
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1719                     raise ExistingVideoReached
#    1720                 break
# -> 1721             return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1722         else:
#    1723             extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in wrapper(self, *args, **kwargs)
#    1730             while True:
#    1731                 try:
# -> 1732                     return func(self, *args, **kwargs)
#    1733                 except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1734                     raise
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in __extract_info(self, url, ie, download, extra_info, process)
#    1886         if process:
#    1887             self._wait_for_video(ie_result)
# -> 1888             return self.process_ie_result(ie_result, download, extra_info)
#    1889         else:
#    1890             return ie_result
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in process_ie_result(self, ie_result, download, extra_info)
#    1965             # We have to add extra_info to the results because it may be
#    1966             # contained in a playlist
# -> 1967             return self.extract_info(
#    1968                 ie_result['url'], download,
#    1969                 ie_key=ie_result.get('ie_key'),
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1719                     raise ExistingVideoReached
#    1720                 break
# -> 1721             return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1722         else:
#    1723             extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in wrapper(self, *args, **kwargs)
#    1730             while True:
#    1731                 try:
# -> 1732                     return func(self, *args, **kwargs)
#    1733                 except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1734                     raise
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in __extract_info(self, url, ie, download, extra_info, process)
#    1886         if process:
#    1887             self._wait_for_video(ie_result)
# -> 1888             return self.process_ie_result(ie_result, download, extra_info)
#    1889         else:
#    1890             return ie_result
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in process_ie_result(self, ie_result, download, extra_info)
#    2015             self._sanitize_thumbnails(ie_result)
#    2016             try:
# -> 2017                 return self.__process_playlist(ie_result, download)
#    2018             finally:
#    2019                 self._playlist_level -= 1
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in __process_playlist(self, ie_result, download)
#    2168                 f'of {self._format_screen(n_entries, self.Styles.EMPHASIS)}')
#    2169
# -> 2170             entry_result = self.__process_iterable_entry(entry, download, collections.ChainMap({
#    2171                 'playlist_index': playlist_index,
#    2172                 'playlist_autonumber': i + 1,
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in wrapper(self, *args, **kwargs)
#    1730             while True:
#    1731                 try:
# -> 1732                     return func(self, *args, **kwargs)
#    1733                 except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1734                     raise
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in __process_iterable_entry(self, entry, download, extra_info)
#    2200     @_handle_extraction_exceptions
#    2201     def __process_iterable_entry(self, entry, download, extra_info):
# -> 2202         return self.process_ie_result(
#    2203             entry, download=download, extra_info=extra_info)
#    2204
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in process_ie_result(self, ie_result, download, extra_info)
#    1965             # We have to add extra_info to the results because it may be
#    1966             # contained in a playlist
# -> 1967             return self.extract_info(
#    1968                 ie_result['url'], download,
#    1969                 ie_key=ie_result.get('ie_key'),
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1719                     raise ExistingVideoReached
#    1720                 break
# -> 1721             return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1722         else:
#    1723             extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in wrapper(self, *args, **kwargs)
#    1748                     self.report_error(msg)
#    1749                 except ExtractorError as e:  # An error we somewhat expected
# -> 1750                     self.report_error(str(e), e.format_traceback())
#    1751                 except Exception as e:
#    1752                     if self.params.get('ignoreerrors'):
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in report_error(self, message, *args, **kwargs)
#    1164         in red if stderr is a tty file.
#    1165         """
# -> 1166         self.trouble(f'{self._format_err("ERROR:", self.Styles.ERROR)} {message}', *args, **kwargs)
#    1167
#    1168     def write_debug(self, message, only_once=False):
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in trouble(self, message, tb, is_error)
#    1102             else:
#    1103                 exc_info = sys.exc_info()
# -> 1104             raise DownloadError(message, exc_info)
#    1105         self._download_retcode = 1
#    1106
#
# DownloadError: ERROR: [youtube] cAq1b7Ssssc: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies

# %%
import zipfile
import glob
from google.colab import files

with zipfile.ZipFile("Songs.zip", "w") as zipf:
    for file in glob.glob("downloads/*.mp3"):
        zipf.write(file, arcname=file.split("/")[-1])

files.download("Songs.zip")

# %%
# !pip -q install spotipy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.4/502.4 kB 10.5 MB/s eta 0:00:00

# %%
import re
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# -------------------------
# Enter your Spotify API credentials
# -------------------------
CLIENT_ID = "2134eb4a7fab4612af6a8f21e8547a30"
CLIENT_SECRET = "32fcfec813dc4ffa8dd5bf82ad1f4574"

auth_manager = SpotifyClientCredentials(
    client_id=CLIENT_ID,
    client_secret=CLIENT_SECRET
)

sp = spotipy.Spotify(auth_manager=auth_manager)

# -------------------------
# Playlist URL
# -------------------------
playlist_url = input("Paste Spotify Playlist URL:\n").strip()

# Extract playlist ID
match = re.search(r"playlist/([a-zA-Z0-9]+)", playlist_url)

if not match:
    raise ValueError("Invalid Spotify playlist URL")

playlist_id = match.group(1)

# -------------------------
# Read all tracks
# -------------------------
songs = []

results = sp.playlist_items(playlist_id)

while True:
    for item in results["items"]:
        track = item["track"]

        if track:
            songs.append(track["name"])

    if results["next"]:
        results = sp.next(results)
    else:
        break

# -------------------------
# Print song names
# -------------------------
print(f"\nFound {len(songs)} songs:\n")

for i, song in enumerate(songs, 1):
    print(f"{i}. {song}")
# Out:
# Paste Spotify Playlist URL:
# https://open.spotify.com/playlist/37i9dQZF1EIXhylBKSKadm?si=cjR1xei4SXWF-7IP70_jjg
# ERROR:spotipy.client:HTTP Error for GET to https://api.spotify.com/v1/playlists/37i9dQZF1EIXhylBKSKadm/items with Params: {'limit': 50, 'offset': 0, 'fields': None, 'market': None, 'additional_types': 'track,episode'} returned 403 due to Active premium subscription required for the owner of the app. When the subscription status changes, it can take a few hours before requests are allowed again.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     270
# --> 271             response.raise_for_status()
#     272             results = response.json()
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in raise_for_status(self)
#    1025         if http_error_msg:
# -> 1026             raise HTTPError(http_error_msg, response=self)
#    1027
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.spotify.com/v1/playlists/37i9dQZF1EIXhylBKSKadm/items?limit=50&offset=0&additional_types=track%2Cepisode
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# /tmp/ipykernel_529/75770623.py in <cell line: 0>()
#      34 songs = []
#      35
# ---> 36 results = sp.playlist_items(playlist_id)
#      37
#      38 while True:
#
# /usr/local/lib/python3.12/dist-packages/spotipy/client.py in playlist_items(self, playlist_id, fields, limit, offset, market, additional_types)
#     740         """
#     741         plid = self._get_id("playlist", playlist_id)
# --> 742         return self._get(
#     743             f"playlists/{plid}/items",
#     744             limit=limit,
#
# /usr/local/lib/python3.12/dist-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     319             kwargs.update(args)
#     320
# --> 321         return self._internal_call("GET", url, payload, kwargs)
#     322
#     323     def _post(self, url, args=None, payload=None, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     289                          f"{args.get('params')} returned {response.status_code} due to {msg}")
#     290
# --> 291             raise SpotifyException(
#     292                 response.status_code,
#     293                 -1,
#
# SpotifyException: http status: 403, code: -1 - https://api.spotify.com/v1/playlists/37i9dQZF1EIXhylBKSKadm/items?limit=50&offset=0&additional_types=track%2Cepisode:
#  Active premium subscription required for the owner of the app. When the subscription status changes, it can take a few hours before requests are allowed again., reason: None

# %%
import yt_dlp
from pathlib import Path

songs = ["Marana Mass - From  Petta", "Karuthavanlaam Galeejaam", "Kaala (Tamil) Teaser Theme", "Sodakku (From  Thaanaa Serndha Koottam )", "Aaluma Doluma", "Naanum Rowdy Dhaan", "Don'u Don'u Don'u - The Don's Romance", "Danga Maari Oodhari", "Maari Thara Local - Here Comes Maari", "What a Karvaad (The Philosophy of Raghuvaran)", "Udhungada Sangu (The Frustration of Raghuvaran)", "Local Boys (From  Ethir Neechal )", "Machi Open the Bottle (From  Mankatha )", "Vip Title Song (The Rise of Raghuvaran)", "Chennai City Gangsta", "Vaanganna Vanakkanganna", "Vilayadu Mankatha (From  Mankatha Full Album )", "Machi Open the Bottle", "Adiyae Kolluthey", "Yethi Yethi", "Ethir Neechal (From  Ethir Neechal )", "Otha Sollaala", "Kalasala Kalasala (From  Osthe )", "The Maari Swag", "Bittu Padam Di", "Theemai Dhaan Vellum - Awakening the Monster", "Naakka Mukka (From  Kadhalil Vizhundhen )", "Aadungada Enna Suthi (From  Pokkiri )", "Maduraiveeranthaane (From  Dhol )", "Tasakku Tasakku", "Kasu Panam - From  Soodhu Kavvum", "Jingunamani", "Pistah", "Yemma Yea Alagamma (From  Vanamagan )", "Karuthavanlaam Galeejaam (From  Velaikkaran )", "Sarakku Vechirukken (From  Shajahaan )", "Mersalaayitten", "Neruppu Da", "Shoot the Kuruvi - From  Jil Jung Juk", "Dandanakka (From  Romeo Juliet )", "Aathangara Orathil", "Madras", "Jalsa (From  Chennai-600028 )", "Jalsa (Remix) (From  Chennai-600028 )", "Mazhai Vara Pogudhae", "Club Le Mabbu Le", "Guleba", "Simtaangaran", "Petta Theme - From  Petta", "Marana Mass - From  Petta", "Kadhal Ara Onnu Vizundhuchu", "Adhaaru Adhaaru", "Chalmaar", "Ullaallaa - From  Petta", "Rowdy Baby", "Thangamey", "Ava Enna", "Area Gaana (Enga Veetu Kuthuvilakkey)", "Verithanam (From  Bigil )", "Appadi Podu", "Uppu Karuvaadu ( From  Mudhalvan )", "Maatikichu", "Orasaadha - Madras Gig", "Kathadikkuthu Kathadikkuthu", "Aaha Kalyanam - From  Petta", "Mukkala Mukkabla", "Namma Kattula", "Urvashi Uravashi", "Takkaru Takkaru", "Shake That", "Meesaya Murukku", "Sonapareeya", "Kadal Raasa Naan", "No Money No Honey", "Nangaai", "Stylish Thamizhachi (From  Arrambam )", "Maari Gethu (From  Maari 2 )", "Oru Kuchi Oru Kulfi #TheSelfieSong - From  Kalakalappu 2", "En Peru Meenakumari", "Thodakkam Mangalyam", "Ale Ale", "Rakita Rakita Rakita (From  Jagame Thandhiram )", "Vaathi Coming (From  Master )", "Chellamma (From  Doctor )", "Dharala Prabhu Title Track (From  Dharala Prabhu )", "Ey Inge Paaru", "Taxi Taxi", "Petta Paraak - From  Petta", "Showkali", "Appadipodu (From  Gilli )", "Thani Oruvan - The Power of One", "Mersalaayitten - Remix", "Secret of Success", "Balle Lakka", "Goa - Club Mix", "Maacho (From  Mersal )", "Girlfriend", "Ladio", "Hey Amigo", "Voda Voda Voda", "Aalaporaan Thamizhan (From  Mersal )", "Vilayaadu Mankatha - Extended Dance Mix", "Top Tucker (From  Sarkar (Tamil) )", "Boomi Enna Suthudhe (From  Ethir Neechal )", "Jimikki Ponnu", "Naa Ready (From  Leo )", "Ranjithame (From  Varisu )", "Kaavaalaa (From  Jailer )", "Bullet Song (From  The Warriorr  )(Tamil)", "Private Party (From  Don )", "Jalabulajangu (From  Don )", "Pathala Pathala (From  Vikram )", "Dippam Dappam (From  Kaathuvaakula Rendu Kaadhal )", "Arabic Kuthu - Halamithi Habibo (From  Beast )", "Two Two Two (From  Kaathuvaakula Rendu Kaadhal )", "Vaathi Coming", "Beast Mode (From  Beast )", "Osarattum Pathu Thala (From  Pathu Thala )", "Raawadi", "Thee Thalapathy (From  Varisu )", "Pacha Elai (From  Love Today )", "Varavaa Varavaa", "Thaai Kelavi (From  Thiruchitrambalam )", "Seena Thana", "Porkanda Singam", "Hey Vetri Velaa", "Rangola", "Manmatha Raasa", "O Podu 1", "Polakattum Para Para", "Manasilaayo (From  Vettaiyan )", "Water Packet (From  Raayan )", "Udhungada Sangu (From  Velai Illa Pattadhaari )", "Aathichoodi (From  TNO7 AL 4777 )", "Jinguchaa (From  Thug Life )", "Sawadeeka (From  Vidaamuyarchi )", "Chikitu Vibe Promo (From  Coolie )", "Peelings (From  Pushpa 2 The Rule ) [TAMIL]", "Makkamishi - From  Brother", "Spark (From  The Greatest Of All Time )", "Kanimaa (From  Retro )"]

output_folder = Path("Download")
output_folder.mkdir(exist_ok=True)

ydl_opts = {
    "format": "bestaudio/best",
    "outtmpl": str(output_folder / "%(title)s.%(ext)s"),
    "default_search": "ytsearch1",
    "noplaylist": True,
    "quiet": True,          # Hide yt-dlp output
    "no_warnings": True,    # Hide warnings

    "postprocessors": [{
        "key": "FFmpegExtractAudio",
        "preferredcodec": "mp3",
        "preferredquality": "320",
    }],
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    total = len(songs)
    success = 0
    failed = 0

    for i, song in enumerate(songs, start=1):
        try:
            ydl.download([song])
            print(f"[{i}/{total}] ✅ {song} - Downloaded")
            success += 1
        except Exception:
            print(f"[{i}/{total}] ❌ {song} - Failed")
            failed += 1

print("\n==============================")
print(f"Total Songs : {total}")
print(f"Downloaded  : {success}")
print(f"Failed      : {failed}")
print("==============================")
# Out:
# ERROR: [youtube] 88iypMO9H7g: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# [1/141] ❌ Marana Mass - From  Petta - Failed
# ERROR: [youtube] es-5OLRrUf8: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# [2/141] ❌ Karuthavanlaam Galeejaam - Failed
# ERROR: [youtube] ADkV3mRCptc: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# [3/141] ❌ Kaala (Tamil) Teaser Theme - Failed
# ERROR: [youtube] pn6M7_L1JbQ: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# [4/141] ❌ Sodakku (From  Thaanaa Serndha Koottam ) - Failed
# ERROR: [youtube] 2ogKpj5QuSY: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# [5/141] ❌ Aaluma Doluma - Failed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4968/1284765654.py in <cell line: 0>()
#      29     for i, song in enumerate(songs, start=1):
#      30         try:
# ---> 31             ydl.download([song])
#      32             print(f"[{i}/{total}] ✅ {song} - Downloaded")
#      33             success += 1
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in download(self, url_list)
#    3713
#    3714         for url in url_list:
# -> 3715             self.__download_wrapper(self.extract_info)(
#    3716                 url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3717
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in wrapper(*args, **kwargs)
#    3686         def wrapper(*args, **kwargs):
#    3687             try:
# -> 3688                 res = func(*args, **kwargs)
#    3689             except CookieLoadError:
#    3690                 raise
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1719                     raise ExistingVideoReached
#    1720                 break
# -> 1721             return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1722         else:
#    1723             extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in wrapper(self, *args, **kwargs)
#    1730             while True:
#    1731                 try:
# -> 1732                     return func(self, *args, **kwargs)
#    1733                 except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1734                     raise
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in __extract_info(self, url, ie, download, extra_info, process)
#    1886         if process:
#    1887             self._wait_for_video(ie_result)
# -> 1888             return self.process_ie_result(ie_result, download, extra_info)
#    1889         else:
#    1890             return ie_result
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in process_ie_result(self, ie_result, download, extra_info)
#    1965             # We have to add extra_info to the results because it may be
#    1966             # contained in a playlist
# -> 1967             return self.extract_info(
#    1968                 ie_result['url'], download,
#    1969                 ie_key=ie_result.get('ie_key'),
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1719                     raise ExistingVideoReached
#    1720                 break
# -> 1721             return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1722         else:
#    1723             extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in wrapper(self, *args, **kwargs)
#    1730             while True:
#    1731                 try:
# -> 1732                     return func(self, *args, **kwargs)
#    1733                 except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1734                     raise
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in __extract_info(self, url, ie, download, extra_info, process)
#    1886         if process:
#    1887             self._wait_for_video(ie_result)
# -> 1888             return self.process_ie_result(ie_result, download, extra_info)
#    1889         else:
#    1890             return ie_result
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in process_ie_result(self, ie_result, download, extra_info)
#    2015             self._sanitize_thumbnails(ie_result)
#    2016             try:
# -> 2017                 return self.__process_playlist(ie_result, download)
#    2018             finally:
#    2019                 self._playlist_level -= 1
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in __process_playlist(self, ie_result, download)
#    2098             ie_result['requested_entries'], ie_result['entries'] = None, None
#    2099         else:
# -> 2100             entries = resolved_entries = list(entries)
#    2101             n_entries = len(resolved_entries)
#    2102             ie_result['requested_entries'], ie_result['entries'] = tuple(zip(*resolved_entries, strict=True)) or ([], [])
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/utils/_utils.py in _iter()
#     776     def _iter():
#     777         seen = []  # Do not use set since the items can be unhashable
# --> 778         for x in iterable:
#     779             if x not in seen:
#     780                 seen.append(x)
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/utils/_utils.py in get_requested_items(self)
#    2483
#    2484         for index in self.parse_playlist_items(playlist_items):
# -> 2485             for i, entry in self[index]:
#    2486                 yield i, entry
#    2487                 if not entry:
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/utils/_utils.py in __getitem__(self, idx)
#    2545                 continue
#    2546             try:
# -> 2547                 entry = self._getter(i)
#    2548             except self.IndexError:
#    2549                 self.is_exhausted = True
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/utils/_utils.py in get_entry(i)
#    2518             def get_entry(i):
#    2519                 try:
# -> 2520                     return type(self.ydl)._handle_extraction_exceptions(lambda _, i: self._entries[i])(self.ydl, i)
#    2521                 except (LazyList.IndexError, PagedList.IndexError):
#    2522                     raise self.IndexError
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in wrapper(self, *args, **kwargs)
#    1730             while True:
#    1731                 try:
# -> 1732                     return func(self, *args, **kwargs)
#    1733                 except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1734                     raise
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/utils/_utils.py in <lambda>(_, i)
#    2518             def get_entry(i):
#    2519                 try:
# -> 2520                     return type(self.ydl)._handle_extraction_exceptions(lambda _, i: self._entries[i])(self.ydl, i)
#    2521                 except (LazyList.IndexError, PagedList.IndexError):
#    2522                     raise self.IndexError
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/utils/_utils.py in __getitem__(self, idx)
#    2283         n = max(start or 0, stop or 0) - len(self._cache) + 1
#    2284         if n > 0:
# -> 2285             self._cache.extend(itertools.islice(self._iterable, n))
#    2286         try:
#    2287             return self._cache[idx]
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/extractor/youtube/_tab.py in _search_results(self, query, params, default_client)
#    1058             headers = self.generate_api_headers(
#    1059                 ytcfg=ytcfg, visitor_data=self._extract_visitor_data(search), default_client=default_client)
# -> 1060             search = self._extract_response(
#    1061                 item_id=f'{display_id} page {page_num}', ep='search', query=data,
#    1062                 default_client=default_client, check_get_keys=check_get_keys, ytcfg=ytcfg, headers=headers)
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/extractor/youtube/_base.py in _extract_response(self, item_id, query, note, headers, ytcfg, check_get_keys, ep, fatal, api_hostname, default_client)
#    1258         while True:
#    1259             try:
# -> 1260                 response = self._call_api(
#    1261                     ep=ep, fatal=True, headers=headers,
#    1262                     video_id=item_id, query=query, note=note,
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/extractor/youtube/_base.py in _call_api(self, ep, query, video_id, fatal, headers, note, errnote, context, api_key, api_hostname, default_client)
#     803         if headers:
#     804             real_headers.update(headers)
# --> 805         return self._download_json(
#     806             f'https://{self._select_api_hostname(api_hostname, default_client)}/youtubei/v1/{ep}',
#     807             video_id=video_id, fatal=fatal, note=note, errnote=errnote,
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/extractor/common.py in download_content(self, url_or_request, video_id, note, errnote, transform_source, fatal, encoding, data, headers, query, expected_status, impersonate, require_impersonation)
#    1146                 kwargs.pop('transform_source')
#    1147             # The method is fetched by name so subclasses can override _download_..._handle
# -> 1148             res = getattr(self, download_handle.__name__)(url_or_request, video_id, **kwargs)
#    1149             return res if res is False else res[0]
#    1150
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/extractor/common.py in download_handle(self, url_or_request, video_id, note, errnote, transform_source, fatal, encoding, data, headers, query, expected_status, impersonate, require_impersonation)
#    1104                             fatal=True, encoding=None, data=None, headers={}, query={}, expected_status=None,
#    1105                             impersonate=None, require_impersonation=False):
# -> 1106             res = self._download_webpage_handle(
#    1107                 url_or_request, video_id, note=note, errnote=errnote, fatal=fatal, encoding=encoding,
#    1108                 data=data, headers=headers, query=query, expected_status=expected_status,
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/extractor/common.py in _download_webpage_handle(self, url_or_request, video_id, note, errnote, fatal, encoding, data, headers, query, expected_status, impersonate, require_impersonation)
#     969             url_or_request = url_or_request.partition('#')[0]
#     970
# --> 971         urlh = self._request_webpage(url_or_request, video_id, note, errnote, fatal, data=data,
#     972                                      headers=headers, query=query, expected_status=expected_status,
#     973                                      impersonate=impersonate, require_impersonation=require_impersonation)
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/extractor/youtube/_base.py in _request_webpage(self, *args, **kwargs)
#     781
#     782     def _request_webpage(self, *args, **kwargs):
# --> 783         response = super()._request_webpage(*args, **kwargs)
#     784
#     785         # Check that we are still logged-in and cookies have not rotated after every request
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/extractor/common.py in _request_webpage(self, url_or_request, video_id, note, errnote, fatal, data, headers, query, expected_status, impersonate, require_impersonation)
#     905
#     906         try:
# --> 907             return self._downloader.urlopen(self._create_request(url_or_request, data, headers, query, extensions))
#     908         except network_exceptions as err:
#     909             if isinstance(err, HTTPError):
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/YoutubeDL.py in urlopen(self, req)
#    4303
#    4304         try:
# -> 4305             return self._request_director.send(req)
#    4306         except NoSupportingHandlers as e:
#    4307             for ue in e.unsupported_errors:
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/networking/common.py in send(self, request)
#     115             self._print_verbose(f'Sending request via "{handler.RH_NAME}"')
#     116             try:
# --> 117                 response = handler.send(request)
#     118             except RequestError:
#     119                 raise
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/networking/_helper.py in wrapper(self, *args, **kwargs)
#     192     def wrapper(self, *args, **kwargs):
#     193         try:
# --> 194             return func(self, *args, **kwargs)
#     195         except RequestError as e:
#     196             if e.handler is None:
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/networking/common.py in send(self, request)
#     357         if not isinstance(request, Request):
#     358             raise TypeError('Expected an instance of Request')
# --> 359         return self._send(request)
#     360
#     361     @abc.abstractmethod
#
# /usr/local/lib/python3.12/dist-packages/yt_dlp/networking/_requests.py in _send(self, request)
#     322
#     323         try:
# --> 324             requests_res = session.request(
#     325                 method=request.method,
#     326                 url=request.url,
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.12/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in getresponse(self)
#     563
#     564         # Get the response from http.client.HTTPConnection
# --> 565         httplib_response = super().getresponse()
#     566
#     567         try:
#
# /usr/lib/python3.12/http/client.py in getresponse(self)
#    1448         try:
#    1449             try:
# -> 1450                 response.begin()
#    1451             except ConnectionError:
#    1452                 self.close()
#
# /usr/lib/python3.12/http/client.py in begin(self)
#     334         # read until we get a non-100 response
#     335         while True:
# --> 336             version, status, reason = self._read_status()
#     337             if status != CONTINUE:
#     338                 break
#
# /usr/lib/python3.12/http/client.py in _read_status(self)
#     295
#     296     def _read_status(self):
# --> 297         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298         if len(line) > _MAXLINE:
#     299             raise LineTooLong("status line")
#
# /usr/lib/python3.12/socket.py in readinto(self, b)
#     718         while True:
#     719             try:
# --> 720                 return self._sock.recv_into(b)
#     721             except timeout:
#     722                 self._timeout_occurred = True
#
# /usr/lib/python3.12/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1249                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250                   self.__class__)
# -> 1251             return self.read(nbytes, buffer)
#    1252         else:
#    1253             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.12/ssl.py in read(self, len, buffer)
#    1101         try:
#    1102             if buffer is not None:
# -> 1103                 return self._sslobj.read(len, buffer)
#    1104             else:
#    1105                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import zipfile
import glob
from google.colab import files

with zipfile.ZipFile("Songs.zip", "w") as zipf:
    for file in glob.glob("Download/*.mp3"):
        zipf.write(file, arcname=file.split("/")[-1])

files.download("Songs.zip")
